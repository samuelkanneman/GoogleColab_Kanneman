# %%
import os
os.environ['PATH'] = os.environ['PATH'] + ';' + '/path/to/ffmpeg/bin'

from pydub import AudioSegment

mp3_audio = AudioSegment.from_mp3("Grabacion.m4a")
mp3_audio.export("Grabacion.wav", format="wav")
