# %%
! apt-get install git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.

# %%
! git clone https://github.com/LMmansilla/Grupo14_Procesamiento.git
# Out:
# Cloning into 'Grupo14_Procesamiento'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 119 (delta 64), reused 31 (delta 10), pack-reused 0
# Receiving objects: 100% (119/119), 1.35 MiB | 2.76 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
# %cd repositorio
# %ls
# %cd Grupo14_Procesamiento
# %ls
# %cd ..
# %cd ..
# %ls
! jupyter PD_valencia hoteles.ipynb
# Out:
# [Errno 2] No such file or directory: 'repositorio'
# /content
# Grupo14_Procesamiento/  sample_data/
# /content/Grupo14_Procesamiento
#  inicio.txt  'PD_valencia hoteles.ipynb'   README.md   valenciahoteles.csv
# /content
# /
# bin@      dev/   lib32@   mnt/                      python-apt/  srv/    usr/
# boot/     etc/   lib64@   NGC-DL-CONTAINER-LICENSE  root/        sys/    var/
# content/  home/  libx32@  opt/                      run/         tmp/
# datalab/  lib@   media/   proc/                     sbin@        tools/
# usage: jupyter
#        [-h]
#        [--version]
#        [--config-dir]
#        [--data-dir]
#        [--runtime-dir]
#        [--paths]
#        [--json]
#        [--debug]
#        [subcommand]
#
# Jupyter:
# Interactive
# Computing
#
# positional arguments:
#   subcommand
#     the
#     subcommand
#     to launch
#
# options:
#   -h, --help
#     show this
#     help
#     message and
#     exit
#   --version
#     show the
#     versions of
#     core
# ...
