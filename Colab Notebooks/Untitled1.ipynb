# %%
uno=['  * ',
'  * ',
'  * ',
'  * ',
'  * ']

dos=['*** ',
'  * ',
'*** ',
'*   ',
'*** ']


for i in range(5):
    print(uno[i] + dos[i])

tres=['*** ',
'  * ',
'*** ',
'  * ',
***]
cuatro='''* *
* *
***
  *
  *'''
cinco='''***
*  
***
  *
***'''
seis='''***
*  
***
* *
***'''
siete='''***
  *
  *
  *
  *'''
ocho='''***
* *
***
* *
***'''
nueve='''***
* *
***
  *
***'''
cero='''***
* *
* *
* *
***'''
